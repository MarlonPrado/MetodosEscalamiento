# %% [markdown]
# Importacion de Pandas, NumPy y Matplotlib

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import matplotlib.pyplot as plt
from IPython.display import display

# %% [markdown]
# Montando la unidad de Drive Personal

# %%
from google.colab import drive
drive.mount('/content/drive') # Se debe dar acceso con token para utilizar Drive
# Out:
# Mounted at /content/drive

# %% [markdown]
# Cargando el Dataset en formato CSV - Creando el DataFrame

# %%
#URL del dataset: https://www.kaggle.com/datasets/imakash3011/customer-personality-analysis
df = pd.read_csv('train.csv')

# %% [markdown]
# Explorando el conjunto de datos desde la consola

# %%
print(df.head())      # Muestra las primeras filas del DataFrame
#print(df.info())      # Proporciona información sobre las columnas y tipos de datos
#print(df.describe())  # Calcula estadísticas resumidas de tus datos
#print(df.columns)
# Out:
#    battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  m_dep  \
# 0            842     0          2.2         0   1       0           7    0.6
# 1           1021     1          0.5         1   0       1          53    0.7
# 2            563     1          0.5         1   2       1          41    0.9
# 3            615     1          2.5         0   0       0          10    0.8
# 4           1821     1          1.2         0  13       1          44    0.6
#
#    mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  talk_time  \
# 0        188        2  ...         20       756  2549     9     7         19
# 1        136        3  ...        905      1988  2631    17     3          7
# 2        145        5  ...       1263      1716  2603    11     2          9
# 3        131        6  ...       1216      1786  2769    16     8         11
# 4        141        2  ...       1208      1212  1411     8     2         15
#
# ...

# %% [markdown]
# Visualizando el dataframe del proyecto

# %%
# Mostrar el DataFrame utilizando la función display()
display(df)
# Out:
#       battery_power  blue  clock_speed  dual_sim  fc  four_g  int_memory  \
# 0               842     0          2.2         0   1       0           7
# 1              1021     1          0.5         1   0       1          53
# 2               563     1          0.5         1   2       1          41
# 3               615     1          2.5         0   0       0          10
# 4              1821     1          1.2         0  13       1          44
# ...             ...   ...          ...       ...  ..     ...         ...
# 1995            794     1          0.5         1   0       1           2
# 1996           1965     1          2.6         1   0       0          39
# 1997           1911     0          0.9         1   1       1          36
# 1998           1512     0          0.9         0   4       1          46
# 1999            510     1          2.0         1   5       1          45
#
#       m_dep  mobile_wt  n_cores  ...  px_height  px_width   ram  sc_h  sc_w  \
# ...

# %% [markdown]
# Otra manera de visualizar

# %%
df.plot.scatter(x='px_width', y='px_height')
plt.show()
